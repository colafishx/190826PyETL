# %%
import datetime as dt
import pandas as pd
import time

def date_range(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + dt.timedelta(n)

start_date=dt.date(2019,9,24)
end_date=dt.date(2020,7,20)
for i in date_range(start_date, end_date):
    gf = pd.read_csv('E:\\DB103RichardC\\python\\190826PyETL\\dataHUB\\googleFlight\\return\\2019-09-23\\google_flight_ret'+i.strftime("%Y-%m-%d")+'.csv')

    # abandon rows w/ missing values
    gf = gf.dropna()

    # filtering flights w/ transfer(s)
    for j in gf.index:
        if gf.loc[j,'ret_stops'] != 0:
            gf = gf.drop(index=j)
        else:
            pass
    gf = gf.drop(columns='ret_stops')

    # transfer time columns data type into correct ones
    gf['ret_etd']=pd.to_datetime(gf['ret_etd'])
    gf['ret_duration'] = [x + ':00' for x in gf['ret_duration']]
    gf['ret_duration']=pd.to_timedelta(gf['ret_duration'])
    gf = gf.drop(columns=['ret_eta'])
    gf.insert(3,'ret_eta',gf['ret_etd'] + gf['ret_duration'])

    # call airline ranking table
    rk = pd.read_csv('E:\\DB103RichardC\\python\\190826PyETL\\dataHUB\\googleFlight\\ar_clean_ret.csv', usecols=['ret_airline','score'])
    # merge the scores into major table
    gk = pd.merge(gf,rk,how='left', on='ret_airline')
    #save files
    gk.to_csv('E:\\DB103RichardC\\python\\190826PyETL\\dataHUB\\googleFlight\\return\\2019-09-23cleaned\\ret'+i.strftime("%Y-%m-%d")+'.csv')
    print(i.strftime("%Y-%m-%d")+'ret file done. Mission runtime=', time.process_time())
# Out:
# 2019-09-24ret file done. Mission runtime= 48.765625
# 2019-09-25ret file done. Mission runtime= 48.78125
# 2019-09-26ret file done. Mission runtime= 48.96875
# 2019-09-27ret file done. Mission runtime= 49.125
# 2019-09-28ret file done. Mission runtime= 49.28125
# 2019-09-29ret file done. Mission runtime= 49.4375
# 2019-09-30ret file done. Mission runtime= 49.59375
# 2019-10-01ret file done. Mission runtime= 49.734375
# 2019-10-02ret file done. Mission runtime= 49.890625
# 2019-10-03ret file done. Mission runtime= 50.0625
# 2019-10-04ret file done. Mission runtime= 50.21875
# 2019-10-05ret file done. Mission runtime= 50.375
# 2019-10-06ret file done. Mission runtime= 50.53125
# 2019-10-07ret file done. Mission runtime= 50.671875
# 2019-10-08ret file done. Mission runtime= 50.8125
# 2019-10-09ret file done. Mission runtime= 50.953125
# 2019-10-10ret file done. Mission runtime= 51.109375
# 2019-10-11ret file done. Mission runtime= 51.296875
# 2019-10-12ret file done. Mission runtime= 51.453125
# 2019-10-13ret file done. Mission runtime= 51.609375
# 2019-10-14ret file done. Mission runtime= 51.75
# 2019-10-15ret file done. Mission runtime= 51.90625
# 2019-10-16ret file done. Mission runtime= 52.046875
# 2019-10-17ret file done. Mission runtime= 52.1875
# 2019-10-18ret file done. Mission runtime= 52.328125
# 2019-10-19ret file done. Mission runtime= 52.46875
# 2019-10-20ret file done. Mission runtime= 52.640625
# 2019-10-21ret file done. Mission runtime= 52.8125
# 2019-10-22ret file done. Mission runtime= 52.953125
# 2019-10-23ret file done. Mission runtime= 53.109375
# 2019-10-24ret file done. Mission runtime= 53.25
# 2019-10-25ret file done. Mission runtime= 53.421875
# 2019-10-26ret file done. Mission runtime= 53.5625
# 2019-10-27ret file done. Mission runtime= 53.703125
# 2019-10-28ret file done. Mission runtime= 53.859375
# 2019-10-29ret file done. Mission runtime= 54.0
# 2019-10-30ret file done. Mission runtime= 54.15625
# 2019-10-31ret file done. Mission runtime= 54.296875
# 2019-11-01ret file done. Mission runtime= 54.4375
# 2019-11-02ret file done. Mission runtime= 54.59375
# 2019-11-03ret file done. Mission runtime= 54.75
# 2019-11-04ret file done. Mission runtime= 54.921875
# 2019-11-05ret file done. Mission runtime= 55.078125
# 2019-11-06ret file done. Mission runtime= 55.21875
# 2019-11-07ret file done. Mission runtime= 55.375
# 2019-11-08ret file done. Mission runtime= 55.53125
# 2019-11-09ret file done. Mission runtime= 55.703125
# 2019-11-10ret file done. Mission runtime= 55.921875
# 2019-11-11ret file done. Mission runtime= 56.09375
# 2019-11-12ret file done. Mission runtime= 56.234375
# 2019-11-13ret file done. Mission runtime= 56.390625
# 2019-11-14ret file done. Mission runtime= 56.53125
# 2019-11-15ret file done. Mission runtime= 56.671875
# 2019-11-16ret file done. Mission runtime= 56.8125
# 2019-11-17ret file done. Mission runtime= 56.96875
# 2019-11-18ret file done. Mission runtime= 57.125
# 2019-11-19ret file done. Mission runtime= 57.296875
# 2019-11-20ret file done. Mission runtime= 57.4375
# 2019-11-21ret file done. Mission runtime= 57.609375
# 2019-11-22ret file done. Mission runtime= 57.78125
# 2019-11-23ret file done. Mission runtime= 57.9375
# 2019-11-24ret file done. Mission runtime= 58.09375
# 2019-11-25ret file done. Mission runtime= 58.265625
# 2019-11-26ret file done. Mission runtime= 58.40625
# 2019-11-27ret file done. Mission runtime= 58.5625
# 2019-11-28ret file done. Mission runtime= 58.71875
# 2019-11-29ret file done. Mission runtime= 58.859375
# 2019-11-30ret file done. Mission runtime= 59.046875
# 2019-12-01ret file done. Mission runtime= 59.203125
# 2019-12-02ret file done. Mission runtime= 59.34375
# 2019-12-03ret file done. Mission runtime= 59.484375
# 2019-12-04ret file done. Mission runtime= 59.625
# 2019-12-05ret file done. Mission runtime= 59.796875
# 2019-12-06ret file done. Mission runtime= 59.96875
# 2019-12-07ret file done. Mission runtime= 60.109375
# 2019-12-08ret file done. Mission runtime= 60.25
# 2019-12-09ret file done. Mission runtime= 60.40625
# 2019-12-10ret file done. Mission runtime= 60.546875
# 2019-12-11ret file done. Mission runtime= 60.703125
# 2019-12-12ret file done. Mission runtime= 60.859375
# 2019-12-13ret file done. Mission runtime= 61.078125
# 2019-12-14ret file done. Mission runtime= 61.21875
# 2019-12-15ret file done. Mission runtime= 61.359375
# 2019-12-16ret file done. Mission runtime= 61.515625
# 2019-12-17ret file done. Mission runtime= 61.671875
# 2019-12-18ret file done. Mission runtime= 61.8125
# 2019-12-19ret file done. Mission runtime= 61.96875
# 2019-12-20ret file done. Mission runtime= 62.109375
# 2019-12-21ret file done. Mission runtime= 62.3125
# 2019-12-22ret file done. Mission runtime= 62.46875
# 2019-12-23ret file done. Mission runtime= 62.609375
# 2019-12-24ret file done. Mission runtime= 62.78125
# 2019-12-25ret file done. Mission runtime= 62.921875
# 2019-12-26ret file done. Mission runtime= 63.09375
# 2019-12-27ret file done. Mission runtime= 63.234375
# 2019-12-28ret file done. Mission runtime= 63.375
# 2019-12-29ret file done. Mission runtime= 63.40625
# 2019-12-30ret file done. Mission runtime= 63.5625
# 2019-12-31ret file done. Mission runtime= 63.71875
# 2020-01-01ret file done. Mission runtime= 63.859375
# 2020-01-02ret file done. Mission runtime= 64.03125
# 2020-01-03ret file done. Mission runtime= 64.203125
# 2020-01-04ret file done. Mission runtime= 64.34375
# 2020-01-05ret file done. Mission runtime= 64.484375
# 2020-01-06ret file done. Mission runtime= 64.640625
# 2020-01-07ret file done. Mission runtime= 64.78125
# 2020-01-08ret file done. Mission runtime= 64.921875
# 2020-01-09ret file done. Mission runtime= 65.078125
# 2020-01-10ret file done. Mission runtime= 65.21875
# 2020-01-11ret file done. Mission runtime= 65.359375
# 2020-01-12ret file done. Mission runtime= 65.515625
# 2020-01-13ret file done. Mission runtime= 65.65625
# 2020-01-14ret file done. Mission runtime= 65.828125
# 2020-01-15ret file done. Mission runtime= 65.96875
# 2020-01-16ret file done. Mission runtime= 66.125
# 2020-01-17ret file done. Mission runtime= 66.28125
# 2020-01-18ret file done. Mission runtime= 66.421875
# 2020-01-19ret file done. Mission runtime= 66.5625
# 2020-01-20ret file done. Mission runtime= 66.703125
# 2020-01-21ret file done. Mission runtime= 66.859375
# 2020-01-22ret file done. Mission runtime= 67.03125
# 2020-01-23ret file done. Mission runtime= 67.171875
# 2020-01-24ret file done. Mission runtime= 67.328125
# 2020-01-25ret file done. Mission runtime= 67.46875
# 2020-01-26ret file done. Mission runtime= 67.640625
# 2020-01-27ret file done. Mission runtime= 67.796875
# 2020-01-28ret file done. Mission runtime= 67.984375
# 2020-01-29ret file done. Mission runtime= 68.140625
# 2020-01-30ret file done. Mission runtime= 68.296875
# 2020-01-31ret file done. Mission runtime= 68.4375
# 2020-02-01ret file done. Mission runtime= 68.578125
# 2020-02-02ret file done. Mission runtime= 68.734375
# 2020-02-03ret file done. Mission runtime= 68.875
# 2020-02-04ret file done. Mission runtime= 69.015625
# 2020-02-05ret file done. Mission runtime= 69.15625
# 2020-02-06ret file done. Mission runtime= 69.296875
# 2020-02-07ret file done. Mission runtime= 69.515625
# 2020-02-08ret file done. Mission runtime= 69.671875
# 2020-02-09ret file done. Mission runtime= 69.828125
# 2020-02-10ret file done. Mission runtime= 69.96875
# 2020-02-11ret file done. Mission runtime= 70.125
# 2020-02-12ret file done. Mission runtime= 70.28125
# 2020-02-13ret file done. Mission runtime= 70.421875
# 2020-02-14ret file done. Mission runtime= 70.59375
# 2020-02-15ret file done. Mission runtime= 70.75
# 2020-02-16ret file done. Mission runtime= 70.890625
# 2020-02-17ret file done. Mission runtime= 71.03125
# 2020-02-18ret file done. Mission runtime= 71.171875
# 2020-02-19ret file done. Mission runtime= 71.3125
# 2020-02-20ret file done. Mission runtime= 71.46875
# 2020-02-21ret file done. Mission runtime= 71.609375
# 2020-02-22ret file done. Mission runtime= 71.75
# 2020-02-23ret file done. Mission runtime= 71.90625
# 2020-02-24ret file done. Mission runtime= 72.046875
# 2020-02-25ret file done. Mission runtime= 72.1875
# 2020-02-26ret file done. Mission runtime= 72.328125
# 2020-02-27ret file done. Mission runtime= 72.53125
# 2020-02-28ret file done. Mission runtime= 72.671875
# 2020-02-29ret file done. Mission runtime= 72.8125
# 2020-03-01ret file done. Mission runtime= 72.953125
# 2020-03-02ret file done. Mission runtime= 73.109375
# 2020-03-03ret file done. Mission runtime= 73.25
# 2020-03-04ret file done. Mission runtime= 73.40625
# 2020-03-05ret file done. Mission runtime= 73.546875
# 2020-03-06ret file done. Mission runtime= 73.6875
# 2020-03-07ret file done. Mission runtime= 73.828125
# 2020-03-08ret file done. Mission runtime= 73.96875
# 2020-03-09ret file done. Mission runtime= 74.109375
# 2020-03-10ret file done. Mission runtime= 74.265625
# 2020-03-11ret file done. Mission runtime= 74.4375
# 2020-03-12ret file done. Mission runtime= 74.578125
# 2020-03-13ret file done. Mission runtime= 74.71875
# 2020-03-14ret file done. Mission runtime= 74.859375
# 2020-03-15ret file done. Mission runtime= 75.0
# 2020-03-16ret file done. Mission runtime= 75.15625
# 2020-03-17ret file done. Mission runtime= 75.296875
# 2020-03-18ret file done. Mission runtime= 75.4375
# 2020-03-19ret file done. Mission runtime= 75.59375
# 2020-03-20ret file done. Mission runtime= 75.78125
# 2020-03-21ret file done. Mission runtime= 75.9375
# 2020-03-22ret file done. Mission runtime= 76.109375
# 2020-03-23ret file done. Mission runtime= 76.25
# 2020-03-24ret file done. Mission runtime= 76.421875
# 2020-03-25ret file done. Mission runtime= 76.5625
# 2020-03-26ret file done. Mission runtime= 76.71875
# 2020-03-27ret file done. Mission runtime= 76.859375
# 2020-03-28ret file done. Mission runtime= 77.0
# 2020-03-29ret file done. Mission runtime= 77.15625
# 2020-03-30ret file done. Mission runtime= 77.296875
# 2020-03-31ret file done. Mission runtime= 77.453125
# 2020-04-01ret file done. Mission runtime= 77.65625
# 2020-04-02ret file done. Mission runtime= 77.8125
# 2020-04-03ret file done. Mission runtime= 77.953125
# 2020-04-04ret file done. Mission runtime= 78.09375
# 2020-04-05ret file done. Mission runtime= 78.25
# 2020-04-06ret file done. Mission runtime= 78.421875
# 2020-04-07ret file done. Mission runtime= 78.5625
# 2020-04-08ret file done. Mission runtime= 78.703125
# 2020-04-09ret file done. Mission runtime= 78.84375
# 2020-04-10ret file done. Mission runtime= 79.0
# 2020-04-11ret file done. Mission runtime= 79.171875
# 2020-04-12ret file done. Mission runtime= 79.34375
# 2020-04-13ret file done. Mission runtime= 79.484375
# 2020-04-14ret file done. Mission runtime= 79.640625
# 2020-04-15ret file done. Mission runtime= 79.78125
# 2020-04-16ret file done. Mission runtime= 79.921875
# 2020-04-17ret file done. Mission runtime= 80.078125
# 2020-04-18ret file done. Mission runtime= 80.234375
# 2020-04-19ret file done. Mission runtime= 80.4375
# 2020-04-20ret file done. Mission runtime= 80.453125
# 2020-04-21ret file done. Mission runtime= 80.65625
# 2020-04-22ret file done. Mission runtime= 80.8125
# 2020-04-23ret file done. Mission runtime= 80.953125
# 2020-04-24ret file done. Mission runtime= 81.09375
# 2020-04-25ret file done. Mission runtime= 81.25
# 2020-04-26ret file done. Mission runtime= 81.40625
# 2020-04-27ret file done. Mission runtime= 81.59375
# 2020-04-28ret file done. Mission runtime= 81.734375
# 2020-04-29ret file done. Mission runtime= 81.90625
# 2020-04-30ret file done. Mission runtime= 82.078125
# 2020-05-01ret file done. Mission runtime= 82.25
# 2020-05-02ret file done. Mission runtime= 82.390625
# 2020-05-03ret file done. Mission runtime= 82.5625
# 2020-05-04ret file done. Mission runtime= 82.703125
# 2020-05-05ret file done. Mission runtime= 82.859375
# 2020-05-06ret file done. Mission runtime= 83.03125
# 2020-05-07ret file done. Mission runtime= 83.21875
# 2020-05-08ret file done. Mission runtime= 83.359375
# 2020-05-09ret file done. Mission runtime= 83.515625
# 2020-05-10ret file done. Mission runtime= 83.703125
# 2020-05-11ret file done. Mission runtime= 83.84375
# 2020-05-12ret file done. Mission runtime= 84.015625
# 2020-05-13ret file done. Mission runtime= 84.15625
# 2020-05-14ret file done. Mission runtime= 84.296875
# 2020-05-15ret file done. Mission runtime= 84.453125
# 2020-05-16ret file done. Mission runtime= 84.59375
# 2020-05-17ret file done. Mission runtime= 84.75
# 2020-05-18ret file done. Mission runtime= 84.890625
# 2020-05-19ret file done. Mission runtime= 85.046875
# 2020-05-20ret file done. Mission runtime= 85.21875
# 2020-05-21ret file done. Mission runtime= 85.359375
# 2020-05-22ret file done. Mission runtime= 85.515625
# 2020-05-23ret file done. Mission runtime= 85.671875
# 2020-05-24ret file done. Mission runtime= 85.84375
# 2020-05-25ret file done. Mission runtime= 86.0625
# 2020-05-26ret file done. Mission runtime= 86.21875
# 2020-05-27ret file done. Mission runtime= 86.375
# 2020-05-28ret file done. Mission runtime= 86.625
# 2020-05-29ret file done. Mission runtime= 86.765625
# 2020-05-30ret file done. Mission runtime= 86.90625
# 2020-05-31ret file done. Mission runtime= 87.0625
# 2020-06-01ret file done. Mission runtime= 87.25
# 2020-06-02ret file done. Mission runtime= 87.40625
# 2020-06-03ret file done. Mission runtime= 87.5625
# 2020-06-04ret file done. Mission runtime= 87.703125
# 2020-06-05ret file done. Mission runtime= 87.859375
# 2020-06-06ret file done. Mission runtime= 88.0
# 2020-06-07ret file done. Mission runtime= 88.15625
# 2020-06-08ret file done. Mission runtime= 88.328125
# 2020-06-09ret file done. Mission runtime= 88.484375
# 2020-06-10ret file done. Mission runtime= 88.640625
# 2020-06-11ret file done. Mission runtime= 88.796875
# 2020-06-12ret file done. Mission runtime= 88.9375
# 2020-06-13ret file done. Mission runtime= 89.09375
# 2020-06-14ret file done. Mission runtime= 89.25
# 2020-06-15ret file done. Mission runtime= 89.40625
# 2020-06-16ret file done. Mission runtime= 89.578125
# 2020-06-17ret file done. Mission runtime= 89.734375
# 2020-06-18ret file done. Mission runtime= 89.890625
# 2020-06-19ret file done. Mission runtime= 90.046875
# 2020-06-20ret file done. Mission runtime= 90.265625
# 2020-06-21ret file done. Mission runtime= 90.40625
# 2020-06-22ret file done. Mission runtime= 90.546875
# 2020-06-23ret file done. Mission runtime= 90.6875
# 2020-06-24ret file done. Mission runtime= 90.859375
# 2020-06-25ret file done. Mission runtime= 91.0
# 2020-06-26ret file done. Mission runtime= 91.1875
# 2020-06-27ret file done. Mission runtime= 91.328125
# 2020-06-28ret file done. Mission runtime= 91.5
# 2020-06-29ret file done. Mission runtime= 91.65625
# 2020-06-30ret file done. Mission runtime= 91.828125
# 2020-07-01ret file done. Mission runtime= 91.96875
# 2020-07-02ret file done. Mission runtime= 92.109375
# 2020-07-03ret file done. Mission runtime= 92.25
# 2020-07-04ret file done. Mission runtime= 92.40625
# 2020-07-05ret file done. Mission runtime= 92.578125
# 2020-07-06ret file done. Mission runtime= 92.734375
# 2020-07-07ret file done. Mission runtime= 92.890625
# 2020-07-08ret file done. Mission runtime= 93.078125
# 2020-07-09ret file done. Mission runtime= 93.21875
# 2020-07-10ret file done. Mission runtime= 93.375
# 2020-07-11ret file done. Mission runtime= 93.53125
# 2020-07-12ret file done. Mission runtime= 93.6875
# 2020-07-13ret file done. Mission runtime= 93.84375
# 2020-07-14ret file done. Mission runtime= 94.0
# 2020-07-15ret file done. Mission runtime= 94.203125
# 2020-07-16ret file done. Mission runtime= 94.375
# 2020-07-17ret file done. Mission runtime= 94.59375
# 2020-07-18ret file done. Mission runtime= 94.75
# 2020-07-19ret file done. Mission runtime= 94.953125
